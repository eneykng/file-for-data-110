# %% [markdown]
# <a href="https://colab.research.google.com/github/eneykng/file-for-data-110/blob/main/project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
print('download complete')
# Out:
# download complete

# %% [markdown]
# ## Sources
# 1. https://www.kaggle.com/datasets/piterfm/2022-ukraine-russian-war/data
#
# Petro Ivaniuk. (2022). 2022 Ukraine Russia War [Data set]. Kaggle. https://doi.org/10.34740/KAGGLE/DS/1967621
#
# 2. https://www.kaggle.com/datasets/piterfm/massive-missile-attacks-on-ukraine

# %%
#upload the datasets
equipment = pd.read_csv('russia_losses_equipment.csv')
people = pd.read_csv('russia_losses_personnel.csv')
missiles_uav = pd.read_csv('missiles_and_uav.csv')
missile_attacks = pd.read_csv('missile_attacks_daily.csv')

# %% [markdown]
# ## DATA EXPLANATION
#
# ## missiles_and_uav.csv and missile_attacks_daily.csv
#
# ### Tracking
#
# * time_start- start attack time,
# * time_end - end attack time,
# * model - missile or UAV type,
# * launch_place - city or region from missiles were launched,
# * target - could be a city in Ukraine, or region of Ukraine or direction, or full Ukraine,
# * carrier - missile launch platform,
# * launched - number of launched missiles or UAVs,
# * destroyed - number of destroyed missiles or UAVs,
# * source - information source (mainly facebook posts)
#
#
# ## russia_losses_equipment.csv and russia_losses_personnel.csv
#
# ### Tracking
#
# * Personnel
# * Prisoner of War (POW) - - has not been tracked since 2022-04-28
# * Aircraft
# * Helicopter
# * Tank
# * Armored Personnel Carrier (APC)
# * Multiple Rocket Launcher (MRL)
# * Field Artillery
# * Military Auto - has not been tracked since 2022-05-01; joined with Fuel Tank into Vehicles and Fuel Tanks
# * Fuel Tank - has not been tracked since 2022-05-01; joined with Military Auto into Vehicles and Fuel Tanks
# * Anti-aircraft warfare
# * Drone - UAV+RPA
# * Naval Ship - Warships, Boats
# * Anti-aircraft Warfare
# * Mobile SRBM System - has not been tracked since 2022-05-01; joined into Cruise Missiles
# * Vehicles and Fuel Tanks - appear since 2022-05-01 as a sum of Fuel Tank and Military Auto
# * Cruise Missiles - appear since 2022-05-01
# * Direction of Greatest Losses - appear since 2022-04-25
# ### Acronyms
# * POW - Prisoner of War,
# * MRL - Multiple Rocket Launcher,
# * APC - Armored Personnel Carrier,
# * SRBM - Short-range ballistic missile,
# * UAV - Unmanned Aerial Vehicle,
# * RPA - Remotely Piloted Vehicle.
# ### Dataset History
#
# 2022-03-02 - dataset is created (after 7 days of the War).

# %%
equipment.head()
# Out:
#          date  day  aircraft  helicopter  tank    APC  field artillery   MRL  \
# 0  2024-04-28  795       348         325  7279  13991            11948  1050
# 1  2024-04-27  794       348         325  7268  13971            11905  1049
# 2  2024-04-26  793       348         325  7262  13957            11867  1049
# 3  2024-04-25  792       348         325  7255  13942            11836  1049
# 4  2024-04-24  791       348         325  7242  13928            11808  1048
#
#    military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# 0            NaN        NaN   9507          26                    776
# 1            NaN        NaN   9485          26                    775
# 2            NaN        NaN   9461          26                    772
# 3            NaN        NaN   9449          26                    772
# 4            NaN        NaN   9439          26                    771
#
#    special equipment  mobile SRBM system greatest losses direction  \
# ...

# %%
people.head()
# Out:
#          date  day  personnel personnel*  POW
# 0  2024-04-28  795     466150      about  NaN
# 1  2024-04-27  794     465054      about  NaN
# 2  2024-04-26  793     463930      about  NaN
# 3  2024-04-25  792     462980      about  NaN
# 4  2024-04-24  791     461940      about  NaN

# %%
missile_attacks.head()
# Out:
#          time_start          time_end               model     launch_place  \
# 0        2024-04-28  2024-04-28 08:00         Unknown UAV   Kherson oblast
# 1        2024-04-28  2024-04-28 08:00      Shahed-136/131   Chauda, Crimea
# 2        2024-04-28  2024-04-28 08:00  Reconnaissance UAV              NaN
# 3        2024-04-28  2024-04-28 08:00               C-300  Belgorod oblast
# 4  2024-04-27 17:00  2024-04-27 17:00            Orlan-10              NaN
#
#                                 target  \
# 0                      Mykolaiv oblast
# 1                              Ukraine
# 2  Dnipropetrovsk oblast, Dnipro Raion
# 3                                 east
# 4  Dnipropetrovsk oblast, Dnipro Raion
#
#                                    destroyed_details carrier  launched  \
# 0                                                NaN     NaN       5.0
# 1  {'Kyiv oblast': 1, 'Vinnytsia oblast': 1, 'Khm...     NaN       4.0
# ...

# %%
missiles_uav.head()
# Out:
#                     model        category national_origin            type  \
# 0         Unknown Missile  cruise missile             NaN             NaN
# 1           X-22 and X-32  cruise missile          russia             NaN
# 2  X-101/X-555 and Kalibr  cruise missile          russia             NaN
# 3                    X-59  cruise missile          russia  air-to-surface
# 4                 X-59MK2  cruise missile          russia     land-attack
#
#                                      launch_platform        name  \
# 0                                                NaN         NaN
# 1                                                NaN         NaN
# 2                                                NaN         NaN
# 3  Su-30MK, Su-24M, MiG-27, Su-17M3/22M4, HAL Tej...  Kh-59 Ovod
# 4                                              Su-57    Kh-59MK2
#
#           name_NATO guidance_system features unit_cost  produced manufacturer
# ...

# %%
#merge two dfs with missiles in on df
missiles = missile_attacks.merge(missiles_uav, how = 'left', on = ['model'])

# %%
missiles.to_csv('missiles.csv')

# %%
missiles.groupby(['category', 'model'], dropna = False)[['launched', 'destroyed']].sum()
# Out:
#                                                                     launched  \
# category               model
# UAV                    Forpost                                           1.0
#                        Granat-4                                          1.0
#                        Lancet                                           96.0
#                        Merlin-VR                                        42.0
#                        Mohajer-6                                         3.0
#                        Orion                                             3.0
#                        Orlan-10                                         77.0
#                        Orlan-10 and Orlan-30 and ZALA and Supercam       7.0
#                        Orlan-10 and Supercam                             4.0
#                        Orlan-10 and ZALA                                 3.0
#                        Orlan-10 and ZALA and Supercam                   18.0
# ...

# %%
#merge russian losses in one df
losses = equipment.merge(people, how = 'left', on = ['date'])

# %%
losses.to_csv('losses.csv')

# %%
losses.head()
# Out:
#          date  day_x  aircraft  helicopter  tank    APC  field artillery  \
# 0  2024-04-28    795       348         325  7279  13991            11948
# 1  2024-04-27    794       348         325  7268  13971            11905
# 2  2024-04-26    793       348         325  7262  13957            11867
# 3  2024-04-25    792       348         325  7255  13942            11836
# 4  2024-04-24    791       348         325  7242  13928            11808
#
#     MRL  military auto  fuel tank  ...  special equipment  mobile SRBM system  \
# 0  1050            NaN        NaN  ...             1971.0                 NaN
# 1  1049            NaN        NaN  ...             1968.0                 NaN
# 2  1049            NaN        NaN  ...             1962.0                 NaN
# 3  1049            NaN        NaN  ...             1946.0                 NaN
# 4  1048            NaN        NaN  ...             1944.0                 NaN
#
# ...
